# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv("rumahLuas.csv")
x = df['x'].values
y = df['y'].values

# %%
slope, intercept, r, p, std_err = stats.linregress(x,y)

print('slope = ', slope)
print('intercept = ', intercept)
print('r = ', r)
# Out:
# slope =  0.10976773783009863
# intercept =  98.24832962138083
# r =  0.7621137132162578

# %%
def myfunc(x):
    return slope * x + intercept

# %%
mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
print('Penjualan rumah jika luas rumah = 1700 yaitu sebesar', myfunc(1700))
# Out:
# Penjualan rumah jika luas rumah = 1700 yaitu sebesar 284.8534839325485
